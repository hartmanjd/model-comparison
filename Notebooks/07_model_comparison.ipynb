# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
results_df= pd.read_csv('results.csv')

results_df = results_df.sort_values('test_rmse', ascending=False)

results_df
# Out:
#                model  train_rmse  test_rmse
# 0  Linear regression    2.435933   2.442001
# 1      Decision tree    1.719722   2.090083
# 2      Random forest    1.377904   1.645008
# 3                KNN    0.788918   1.076540
# 4                SVR    0.057602   0.076967
# 5                GPR    0.044150   0.045730
# 6                GPR    0.000231   0.000241

# %%
plt.barh(results_df['model'], results_df['test_rmse'])

plt.xlabel('Test RMSE')
plt.title('Model comparison — Test RMSE')
plt.tight_layout()
plt.show()
